# %%
import numpy as np 
import matplotlib.pyplot as plt 
import os 
import pandas as pd
from scipy.signal import savgol_filter as sg
from matplotlib.colors import LogNorm
folder = '/Volumes/RDS/project/laserprojectsmatthews/live/Kasia_RDS/SolidHHG/20221006'

# %%
file_list = os.listdir(folder)
file_list.sort()
file_list.remove('.DS_Store')

# %% [markdown]
# # In air

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and 'bbo' in file and 'wedge' in file and 'repeat' not in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.ylim(10)
plt.xlim(600,1000)
# Out:
# (600.0, 1000.0)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and 'Fundamnetal' in file and 'nosample' in file and 'optimised' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 31,3)
        spec = spec - 3100
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.ylim(0)
# Out:
# (0.0, 525.3642257339743)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 31,3)
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.ylim(600, 700)
# Out:
# (600.0, 700.0)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'wedge' in file and 'd_5_' not in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 31,3)
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.semilogy()
plt.ylim(500)
# Out:
# (500, 89389.17087595836)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'wedge' in file and 'd_5_' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 31,3)
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.xlim(400,900)
plt.ylim(500)
# Out:
# (500.0, 2654.982137904621)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'wedge' in file and 'd_5_' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 31,3)
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.xlim(200,400)
plt.ylim(500,750)
# Out:
# (500.0, 750.0)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and 'bbo' in file and 'repeat' in file and '2nd' in file and 'mmNaCl' not in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)

plt.semilogy()
plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.ylim(20)
# Out:
# (20, 143407.6491018152)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and 'bbo' in file and 'repeat' in file and '2nd' in file and '2mmNaCl' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.ylim(10)
plt.xlim(700,1000)
# Out:
# (700.0, 1000.0)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and 'bbo' in file and 'repeat' in file and '2nd' in file and '4mmNaCl' in file and 'rotation' not in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)

plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.ylim(10)
plt.xlim(700,1000)
# Out:
# (700.0, 1000.0)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and 'bbo' in file and 'repeat' in file and '2nd' in file and '4mmNaCl' in file and 'rotation' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.ylim(10)
plt.xlim(700,1000)
# Out:
# (700.0, 1000.0)

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and 'bbo' in file and 'quartz' in file and 'FEL' not in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s)


plt.legend(bbox_to_anchor = (1,1), loc = 2)

# %% [markdown]
# # Vacuum

# %%
folder = '/Volumes/RDS/project/laserprojectsmatthews/live/Kasia_RDS/SolidHHG/20221006/vacuum'

# %%
file_list = os.listdir(folder)
file_list.sort()

# %%
N = 4
plt.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.rainbow(np.linspace(0.3,1,N)))

# %%
fig, ax = plt.subplots(2, sharex = True, sharey=True)
bg = np.mean(np.load(os.path.join(folder,'fund_background_spectra.npy'))[:,2:], axis=0)
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and 'fund' in file and 'nosample' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = spec - bg
        spec = sg(spec, 21,3)
        wl = np.load(os.path.join(folder, file_wl))[2:]
        ax[0].plot(wl, spec, label = file_s, alpha=0.7)
    if 'npy' in file and 'fund' in file and '_sample' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = spec - bg
        spec = sg(spec, 21,3)
        wl = np.load(os.path.join(folder, file_wl))[2:]
        name = int(file_s.split('_')[2][:-2])
        ax[1].plot(wl, spec, label = name, alpha=0.7)

plt.legend(bbox_to_anchor = (1,1.5), loc = 2, title='Iris Diameter [mm]')
ax[0].set_ylabel('MIR Spectrum no sample')
ax[1].set_ylabel('MIR Spectrum with sample')
ax[1].set_xlabel('Wavelength [nm]')
ax[1].set_xlim(1100)
plt.tight_layout()

# %%
N = 13
plt.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.rainbow(np.linspace(0.3,1,N)))

# %%
fig, ax = plt.subplots(2, sharex=True)
N = 13
iris = np.zeros(N)
pic = np.zeros((N, len(wl)))
count = 0
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'repeat' not in file and 'set8' not in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        wl = np.load(os.path.join(folder, file_wl))[2:]
        pic[count] = spec
        name = int(file_s.split('_')[2][:-2])
        ax[0].plot(wl, spec, label = name, alpha=0.7)
        iris[count] = name
        count +=1


ax[0].legend(bbox_to_anchor = (-0.15,1), loc = 1)
ax[0].semilogy()
ax[0].set_ylim(500)
X,Y = np.meshgrid(wl,iris)
im = ax[1].pcolormesh(X,Y, pic, norm = LogNorm(vmin = 500), cmap = 'rainbow')
cbar_ax = fig.add_axes([1, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)
ax[0].set_ylabel('Spectrometer Counts')
ax[1].set_ylabel('Iris Diameter [mm]')
ax[1].set_xlabel('wavelength [nm]')
ax[1].set_xlim(400,900)
# Out:
# (400.0, 900.0)

# %%
N = 16
plt.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.rainbow(np.linspace(0.3,1,N)))

# %%
fig, ax = plt.subplots(2, sharex=True)
N = 16
iris = np.zeros(N)
pic = np.zeros((N, len(wl)))
count = 0
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'repeat' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        wl = np.load(os.path.join(folder, file_wl))[2:]
        pic[count] = spec
        name = int(file_s.split('_')[3][:-2])
        if name >5 and name !=12:
            name = name/10
        ax[0].plot(wl, spec, label = name, alpha=0.7)
        iris[count] = name
        count +=1



ax[0].legend(bbox_to_anchor = (-0.15,1), loc = 1)
# ax[0].semilogy()
X,Y = np.meshgrid(wl,iris)
im = ax[1].pcolormesh(X,Y, pic, norm = LogNorm(vmin = 550,vmax =650), cmap = 'rainbow')
cbar_ax = fig.add_axes([1, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)
ax[0].set_ylabel('Spectrometer Counts')
ax[1].set_ylabel('Iris Diameter [mm]')
ax[1].set_xlabel('wavelength [nm]')
ax[1].set_xlim(250,440)
ax[0].set_ylim(540,650)
# Out:
# (540.0, 650.0)

# %%
fig, ax = plt.subplots(2, sharex=True)
N = 16
iris = np.zeros(N)
pic = np.zeros((N, len(wl)))
count = 0
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'repeat' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        wl = np.load(os.path.join(folder, file_wl))[2:]
        pic[count] = spec
        name = int(file_s.split('_')[3][:-2])
        if name >5 and name !=12:
            name = name/10
        ax[0].plot(wl, spec, label = name, alpha=0.7)
        iris[count] = name
        count +=1



ax[0].legend(bbox_to_anchor = (-0.15,1), loc = 1)
# ax[0].semilogy()
X,Y = np.meshgrid(wl,iris)
im = ax[1].pcolormesh(X,Y, pic, norm = LogNorm(vmin = 550), cmap = 'rainbow')
cbar_ax = fig.add_axes([1, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)
ax[0].set_ylabel('Spectrometer Counts')
ax[1].set_ylabel('Iris Diameter [mm]')
ax[1].set_xlabel('wavelength [nm]')
ax[1].set_xlim(450,900)
# Out:
# (450.0, 900.0)

# %%
N = 9
plt.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.rainbow(np.linspace(0.3,1,N)))

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'set8' in file and 'NaCl' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
#         spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s, alpha=0.7)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
# plt.semilogy()
plt.ylim(550)
# plt.xlim(500,700)
# Out:
# (550.0, 68931.0740439956)

# %%
dictionary = {'1st wedge':[], '2nd wedge':[], 'wl':[], 'spec':[]}

# %%
N = 7
plt.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.rainbow(np.linspace(0.3,1,N)))

# %%
fig, ax = plt.subplots(2, sharex=True)
N = 7
iris = np.zeros(N)
pic = np.zeros((N, len(wl)))
count = 0
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'set8' in file and '10mm' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
#         spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        pic[count] = spec
        name = int(file_s.split('_')[4][5:])
        ax[0].plot(wl, spec, label = name, alpha=0.7)
        iris[count] = name
        count +=1
        w1 = file.split('_')[4][5:]
        dictionary['1st wedge'].append(int(w1))
        dictionary['2nd wedge'].append(10)
        dictionary['wl'].append(wl)
        dictionary['spec'].append(spec)



ax[0].legend(bbox_to_anchor = (-0.15,1), loc = 1)
# ax[0].semilogy()
X,Y = np.meshgrid(wl,iris)
im = ax[1].pcolormesh(X,Y, pic, norm = LogNorm(vmin = 550), cmap = 'rainbow')
cbar_ax = fig.add_axes([1, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)
ax[0].set_ylabel('Spectrometer Counts')
ax[1].set_ylabel('1st wedge relative insertion [mm]')
ax[0].set_title('2nd wedge 10 mm in')
ax[1].set_xlabel('wavelength [nm]')
ax[1].set_xlim(450,900)
plt.show()

# %%
N = 9
plt.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.rainbow(np.linspace(0.3,1,N)))

# %%
fig, ax = plt.subplots(2, sharex=True)
N = 9
iris = np.zeros(N)
pic = np.zeros((N, len(wl)))
count = 0
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'set8' in file and '5mm' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
#         spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        pic[count] = spec
        name = int(file_s.split('_')[4][5:])
        ax[0].plot(wl, spec, label = name, alpha=0.7)
        iris[count] = name
        count +=1
        w1 = file.split('_')[4][5:]
        dictionary['1st wedge'].append(int(w1))
        dictionary['2nd wedge'].append(5)
        dictionary['wl'].append(wl)
        dictionary['spec'].append(spec)



ax[0].legend(bbox_to_anchor = (-0.15,1), loc = 1)
# ax[0].semilogy()
X,Y = np.meshgrid(wl,iris)
im = ax[1].pcolormesh(X,Y, pic, norm = LogNorm(vmin = 550), cmap = 'rainbow')
cbar_ax = fig.add_axes([1, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)
ax[0].set_ylabel('Spectrometer Counts')
ax[1].set_ylabel('1st wedge relative insertion [mm]')
ax[0].set_title('2nd wedge 5 mm in')
ax[1].set_xlabel('wavelength [nm]')
ax[1].set_xlim(450,900)
ax[0].set_ylim(550)
plt.show()

# %%
N = 10
plt.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.rainbow(np.linspace(0.3,1,N)))

# %%
fig, ax = plt.subplots(2, sharex=True)
N = 10
iris = np.zeros(N)
pic = np.zeros((N, len(wl)))
count = 0
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' not in file and 'set8' in file and '10mm' not in file and '5mm' not in file and 'NaCl' not in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
        w1 = file_s.split('_')[3][5:]
        wl = np.load(os.path.join(folder, file_wl))[2:]
        pic[count] = spec
        name = int(file_s.split('_')[3][5:])
        ax[0].plot(wl, spec, label = name, alpha=0.7)
        iris[count] = name
        count +=1
        dictionary['1st wedge'].append(int(w1))
        dictionary['2nd wedge'].append(0)
        dictionary['wl'].append(wl)
        dictionary['spec'].append(spec)
        


ax[0].legend(bbox_to_anchor = (-0.15,1), loc = 1)
# ax[0].semilogy()
X,Y = np.meshgrid(wl,iris)
im = ax[1].pcolormesh(X,Y, pic, norm = LogNorm(vmin = 550), cmap = 'rainbow')
cbar_ax = fig.add_axes([1, 0.15, 0.05, 0.7])
fig.colorbar(im, cax=cbar_ax)
ax[0].set_ylabel('Spectrometer Counts')
ax[1].set_ylabel('1st wedge relative insertion [mm]')
ax[0].set_title('2nd wedge 0 mm in')
ax[1].set_xlabel('wavelength [nm]')
ax[1].set_xlim(450,900)
plt.show()

# %%
for f in range(len(file_list))[::2]:
    file = file_list[f]
    if 'npy' in file and '3rd' in file and 'nosample' in file:
        file_s = file 
        file_wl = file.split('_')[:-1]
        file_wl.append('wavelength.npy')
        file_wl = '_'.join(file_wl)
        spec  = np.mean(np.load(os.path.join(folder,file_s))[:,2:], axis=0)
        spec = sg(spec, 21,3)
#         spec = spec - np.mean(spec[300:400])
        wl = np.load(os.path.join(folder, file_wl))[2:]
        plt.plot(wl, spec, label = file_s, alpha=0.7)


plt.legend(bbox_to_anchor = (1,1), loc = 2)
plt.semilogy()
plt.ylim(550)
plt.xlim(400,900)
# Out:
# (400.0, 900.0)

# %%
df = pd.DataFrame(dictionary)

# %%
w1_0 = min(df['1st wedge'].to_numpy())
df['1st inserted'] = (df['1st wedge'].to_numpy()-w1_0)*np.tan(np.deg2rad(4))
df['2nd inserted'] = (df['2nd wedge'].to_numpy())*np.tan(np.deg2rad(4))
df['glass inserted'] = df['1st inserted'].to_numpy()+df['2nd inserted'].to_numpy()

# %%
df = df.sort_values(by='glass inserted').reset_index().drop('index', axis=1)

# %%
df
# Out:
#     1st wedge  2nd wedge                                                 wl  \
# 0           7          0  [186.57472834784386, 187.044628862673, 187.514...
# 1           9          0  [186.57472834784386, 187.044628862673, 187.514...
# 2          11          0  [186.57472834784386, 187.044628862673, 187.514...
# 3          13          0  [186.57472834784386, 187.044628862673, 187.514...
# 4          15          0  [186.57472834784386, 187.044628862673, 187.514...
# 5          17          0  [186.57472834784386, 187.044628862673, 187.514...
# 6          19          0  [186.57472834784386, 187.044628862673, 187.514...
# 7           9         10  [186.57472834784386, 187.044628862673, 187.514...
# 8          11         10  [186.57472834784386, 187.044628862673, 187.514...
# 9          21          0  [186.57472834784386, 187.044628862673, 187.514...
# 10         23          0  [186.57472834784386, 187.044628862673, 187.514...
# ...

# %%
N = 26
plt.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.rainbow(np.linspace(0.3,1,N)))

# %%
wedge_trace = np.zeros((N, len(df['wl'][0])))
glass_thickness = np.zeros(N)
for i in df.index:
    plt.plot(df['wl'][i], df['spec'][i], label = '2nd wedge {} total glass {}'.format(df['2nd wedge'][i],df['glass inserted'][i]))
    wedge_trace[i] = df['spec'][i]
    glass_thickness[i] = df['glass inserted'][i]
    
plt.legend(loc = 2, bbox_to_anchor=(1,1))

# %%
X,Y = np.meshgrid(df['wl'][i], glass_thickness)
plt.pcolormesh(X,Y,wedge_trace, norm = LogNorm(vmin=550), cmap = 'rainbow')
plt.colorbar()

# %%
df_max = df[(df['glass inserted']<1)&(df['glass inserted']>0.9)]

# %%
df_max
# Out:
#     1st wedge  2nd wedge                                                 wl  \
# 12         15          5  [186.57472834784386, 187.044628862673, 187.514...
# 13         11         10  [186.57472834784386, 187.044628862673, 187.514...
# 14         21          0  [186.57472834784386, 187.044628862673, 187.514...
#
#                                                  spec  1st inserted  \
# 12  [161.7006653424215, 154.07051010325074, 150.82...      0.559414
# 13  [155.47330436127012, 148.95266789680295, 146.6...      0.279707
# 14  [158.71904105159837, 149.8795429472183, 145.74...      0.978975
#
#     2nd inserted  glass inserted
# 12      0.349634        0.909049
# 13      0.699268        0.978975
# 14      0.000000        0.978975

# %%
N = 3
plt.rcParams['axes.prop_cycle'] = plt.cycler("color", plt.cm.rainbow(np.linspace(0.3,1,N)))

# %%
for i in df_max.index:
    min_term = 550
    norm_term = max(df['spec'][i])
    spec = df['spec'][i]
    base = np.mean(spec[75:125])
    spec = spec-base
    spec[spec<0] = 0
    norm_term = max(spec)
    spec = spec/norm_term
    plt.semilogy(df['wl'][i], spec, '.', label =' 1st wedge {}, 2nd wedge {}, total glass {}'.format(df_max['1st wedge'][i],df_max['2nd wedge'][i],df_max['glass inserted'][i]))
    

plt.legend(loc = 2, bbox_to_anchor = (1,1))

plt.xlabel('Wavelength [nm]')
plt.ylabel('Spectrometer Counts')
# Out:
# Text(0, 0.5, 'Spectrometer Counts')
